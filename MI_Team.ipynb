# %%
# !dir

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('MI.csv')

# %%
df.head()
# Out:
#               Name    pts  Matches  Wickets  Dots  Fours  Sixes  Catches  \
# 0    Hardik Pandya  342.0       16       14    94     28     29       11
# 1  Quinton de Kock  247.5       16        0     0     45     25       17
# 2   Jasprit Bumrah  240.5       16       19   169      0      0        2
# 3    Krunal Pandya  211.0       16       12    94     18      5        5
# 4     Rahul Chahar  183.0       13       13   125      2      0        3
#
#    Stumpings
# 0          0
# 1          2
# 2          0
# 3          0
# 4          0

# %%
df = df.sort_values(by='Matches',ascending=False).reset_index(drop=True)

# %%
df
# Out:
#                     Name    pts  Matches  Wickets  Dots  Fours  Sixes  \
# 0          Hardik Pandya  342.0       16       14    94     28     29
# 1         Jasprit Bumrah  240.5       16       19   169      0      0
# 2          Krunal Pandya  211.0       16       12    94     18      5
# 3       Suryakumar Yadav  170.0       16        0     0     45     10
# 4         Kieron Pollard  132.0       16        0     0     14     22
# 5        Quinton de Kock  247.5       16        0     0     45     25
# 6           Rohit Sharma  175.0       15        0     0     52     10
# 7           Rahul Chahar  183.0       13       13   125      2      0
# 8         Lasith Malinga  149.5       12       16    91      0      0
# 9           Ishan Kishan   39.0        7        0     0      8      4
# 10     Jason Behrendorff   71.5        5        5    54      0      0
# 11  Mitchell McClenaghan   60.5        5        3    45      2      0
# ...

# %%
# Selecting Top 11 players
df = df.iloc[:11,:]

# %%
df
# Out:
#                  Name    pts  Matches  Wickets  Dots  Fours  Sixes  Catches  \
# 0       Hardik Pandya  342.0       16       14    94     28     29       11
# 1      Jasprit Bumrah  240.5       16       19   169      0      0        2
# 2       Krunal Pandya  211.0       16       12    94     18      5        5
# 3    Suryakumar Yadav  170.0       16        0     0     45     10        9
# 4      Kieron Pollard  132.0       16        0     0     14     22        8
# 5     Quinton de Kock  247.5       16        0     0     45     25       17
# 6        Rohit Sharma  175.0       15        0     0     52     10        4
# 7        Rahul Chahar  183.0       13       13   125      2      0        3
# 8      Lasith Malinga  149.5       12       16    91      0      0        1
# 9        Ishan Kishan   39.0        7        0     0      8      4        2
# 10  Jason Behrendorff   71.5        5        5    54      0      0        0
#
#     Stumpings
# 0           0
# 1           0
# ...

# %%
x = df.iloc[:,3:]
y = df['pts']

# %%
# Independent variables
x
# Out:
#     Wickets  Dots  Fours  Sixes  Catches  Stumpings
# 0        14    94     28     29       11          0
# 1        19   169      0      0        2          0
# 2        12    94     18      5        5          0
# 3         0     0     45     10        9          0
# 4         0     0     14     22        8          0
# 5         0     0     45     25       17          2
# 6         0     0     52     10        4          0
# 7        13   125      2      0        3          0
# 8        16    91      0      0        1          0
# 9         0     0      8      4        2          0
# 10        5    54      0      0        0          0

# %%
# Dependent variables
y
# Out:
# 0     342.0
# 1     240.5
# 2     211.0
# 3     170.0
# 4     132.0
# 5     247.5
# 6     175.0
# 7     183.0
# 8     149.5
# 9      39.0
# 10     71.5
# Name: pts, dtype: float64

# %% [markdown]
# # Calculation player's point

# %%
from sklearn import linear_model

# %%
clf = linear_model.LinearRegression()

# %%
clf.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
clf.predict(x)
# Out:
# array([342. , 240.5, 211. , 170. , 132. , 247.5, 175. , 183. , 149.5,
#         39. ,  71.5])

# %% [markdown]
# # y = β 0 + β 1 X 1 + β 2 X 2 + β 3 X 3 + β 4 X 4 + β 5 X 5 + β 6 X 6

# %%
# values of β1, β2, β3, β4, β5, β6
clf.coef_
# Out:
# array([3.5, 1. , 2.5, 3.5, 2.5, 2.5])

# %%
# β0
clf.intercept_
# Out:
# -8.526512829121202e-14

# %%
val = y.values

# %%
ls_val = list(val)
ls_val
# Out:
# [342.0, 240.5, 211.0, 170.0, 132.0, 247.5, 175.0, 183.0, 149.5, 39.0, 71.5]

# %% [markdown]
# # Calculating Team Weight

# %%
# MI Team Weight
MI_Team_weight = 0
for i in ls_val:
   MI_Team_weight += i
print(MI_Team_weight//16)
# Out:
# 122.0
